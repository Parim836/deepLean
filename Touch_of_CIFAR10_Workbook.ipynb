# %% [markdown]
# **รายชื่อสมาชิกในกลุ่ม** (ดับเบิลคลิกหรือดับเบิลแท็บเซลล์นี้เพื่อกรอกข้อมูล) <br>
# <font color='blue'>(พื้นที่สำหรับกรอก) </font><br/>
# 1. 650710076 ณัฐณิชา เวียงวิราศไพศาล
# 2. 650710592 หฤณชนก พนมวรชัย
# 3. 650710836 พัชราพร ภายไธสง
#
# เป็นส่วนหนึ่งของวิชา 5177433, Deep Learning For Computer Vision, อ.ดร.ภูริวัจน์ วรวิชัยพัฒน์

# %% [markdown]
# **ข้อตกลง**
# ถึงแม้จะเป็นงานกลุ่ม แต่ตามแนวคิดของการจัดระบบการเรียนรู้ในประเทศที่พัฒนาแล้วยอมรับ เราจะต้องให้แต่ละคนลงมือคิดลงมือทำด้วยตัวเองก่อน จากนั้นจึงค่อยมาตรวจคำตอบจากแต่ละคนในกลุ่ม หากในกลุ่มมีใครที่เร็วกว่าเพื่อนเป็นพิเศษ คนนั้นจะต้องเปิดโอกาสให้เพื่อนได้ลองค้นหาคำตอบด้วยตัวเองก่อน จะไม่บอกเพื่อนร่วมกลุ่มจนกว่าเขาจะได้พยายามแล้วและเพื่อนเป็นคนถามหาคำตอบหรือคำใบ้เอง
#
# ที่ต้องทำอย่างนี้เพื่อให้แต่ละคนได้มีโอกาสพัฒนาทักษะในการอ่าน การวิเคราะห์ และได้ลองผิดลองถูกด้วยตนเอง ซึ่งขั้นตอนเหล่านี้แท้จริงก็มีความสนุกเพลิดเพลินอยู่ในตัวของมันเองระดับหนึ่ง เพราะแบบฝึกหัดนี้ไม่ใช่การทดสอบว่าแต่ละคนเข้าใจเนื้อหาหรือไม่ แต่เป็นการให้แต่ละคนได้ค้นพบความรู้ที่ซ่อนอยู่ในเนื้อหารายวิชาต่างหาก
#
# ในตอนแรกของการเดินทางจะรู้สึกหวาดกลัว ไม่อยากทำ แต่เมื่อเริ่มเข้าใจกระบวนการค้นพบความรู้แล้ว เราถึงจะเข้าใจอรรถรสในการศึกษาได้ การรีบบอกคำตอบจะไม่ต่างอะไรกับสปอยล์หนัง ดังนั้นในงานกลุ่มนี้ ขอให้มีข้อตกลงกันว่า
# 1. ทุกคนเริ่มทำแบบฝึกหัดด้วยตนเอง จะแยกทำที่บ้านหรือเรียกมาสุมหัวทำพร้อมกันก็ได้
# 2. ให้หยุดเช็กสภาพความก้าวหน้าทุกข้อย่อย คือเมื่อทำข้อ 1 เสร็จแล้วให้ตรวจคำตอบกับเพื่อนในกลุ่มด้วยว่าเข้าใจข้อ 1 ตรงกันหรือไม่ แล้วทำข้อ 2 ข้อ 3 ไปในรูปแบบเดียวกัน ถ้ามีคนช้า ให้รอคนช้าได้คิดด้วยตนเองก่อนสักพัก อย่าเร่งอีกฝ่ายมากเกินไป และคนช้าอย่ามัวแต่ social ให้ใส่ใจกับงานให้เต็มที่ ไม่งั้นทีมจะแตก
# 3. เนื้อหาตรงไหนถ้าทำได้แต่ไม่เข้าใจ (คือโค้ดมันออก แต่ไม่รู้ว่าทำไม) เราควรจะหาคำอธิบายตัวเองให้ได้ก่อน ถ้าไม่ได้จึงค่อยปรึกษาเพื่อนเพื่อหาคำอธิบาย
# 4. ถ้าในกลุ่มติดแบบยกทีม ไม่มีใครทำได้ ให้ปรึกษากันในกลุ่มก่อน ว่าแต่ละคนรู้และทดลองอะไรมาบ้าง เข้าใจแต่ละส่วนว่าอย่างไร ให้อธิบายความเข้าใจของตัวเองให้เพื่อนในกลุ่มรู้ก่อน จะได้แก้ไขความเข้าใจผิดของสมาชิกในกลุ่มให้เรียบร้อย
# 5. อย่าบอกคำตอบเพื่อนจนกว่าจะถึงเวลาอันสมควร และก่อนจะบอก ขอให้คนที่อยากรู้คำตอบพยายามอธิบายว่าตัวเองรู้และเข้าใจอะไรบ้างให้เพื่อนฟัง และคนที่รู้คำตอบไม่จำเป็นต้องบอกเพื่อนตรง ๆ แต่อาจจะถามคำถามเพื่อให้เพื่อนคิดไปในทิศทางที่มีประโยชน์มากขึ้น เพราะบางทีคุณอาจจะพบว่าเพื่อนเข้าใจผิดเพียงเล็กน้อย ถ้าผ่านจุดนั้นไปได้ ที่เหลือเขาจัดการได้เอง
# 6. การปรึกษาข้ามกลุ่มสามารถทำได้ แต่ไม่ใช่ว่าจะเป็นการลอกกัน และต้องปรึกษาน้อย ๆ คิดและค้นหาคำตอบด้วยตัวเองมาก ๆ
#
# **ขยายความข้อตกลงที่ 2** คนที่ทำเสร็จเร็ว ไม่จำเป็นต้องรอเพื่อก่อนลุยข้อต่อ ๆ ไป แต่ต้องเปิดโอกาสให้ทีมมาเช็คคำตอบหรือหาคำใบ้คำอธิบายต่าง ๆ เป็นระยะเพื่อปรับระดับความเข้าใจให้เพียงพอต่อการทำข้อต่อไปได้ด้วยตัวเองทุกคน
#
# ซึ่งขั้นตอนการพักเพื่อปรับระดับความเข้าใจนี้ ตามศัพท์การเรียนรู้เราเรียกว่า 'Leveling' เป็นกลไกที่จะทำให้ทุกคนในทีมเดินหน้าไปสู้กับปัญหาในด่านต่อไปด้วยกันได้ ถ้าไม่ปรับระดับจะมีคนถูกทิ้งไว้ข้างหลังและกลายเป็นชาวเกาะไป และเพื่อนจะรู้สึกว่าตัวเองด้อยค่าไปเรื่อย ๆ ทั้งที่ก็มีศักยภาพในการแก้ปัญหาติดตัวอยู่

# %% [markdown]
# ## จุดประสงค์การเรียนรู้
# ในแบบฝึกหัดนี้ เราจะทดลองนำสิ่งที่เราเรียนรู้จากฐานข้อมูล Fashion MNIST มาใช้กับฐานข้อมูล CIFAR10 ซึ่งเป็นฐานข้อมูลภาพถ่ายที่นิยมใช้ในการเรียนรู้และทดสอบความสามารถของตัวแบบ (model) ต่าง ๆ ที่เราสนใจ ซึ่งภาพใน CIFAR10 ถูกจัดให้เป็นรูปแบบที่ใช้งานง่ายเรียบร้อยแล้วคือมีขนาดเท่ากันหมด 32x32 พิกเซล มีการแบ่งเซ็ตของชุดฝึก (training set) และชุดทดสอบ (test set) ให้เรียบร้อย สิ่งที่ทำให้ข้อมูลชุดนี้เป็นที่นิยมอีกประการหนึ่งก็คือมันเป็นภาพสีขนาดเล็ก ทำให้การทดลองที่เกี่ยวกับภาพถ่ายทำได้อย่างรวดเร็ว เป็นการทดสอบสมมติฐานเบื้องต้นเกี่ยวกับความดีความแย่ของตัวแบบที่เราสนใจได้<br>
# ซึ่งในปัจจุบัน นักวิจัยยังนิยมใช้ฐานข้อมูลนี้เป็นหนึ่งในชุดทดสอบสมรรถนะ (performance benchmark) ของตัวแบบหรือวิธีการขยายข้อมูล (ย้ำว่าเป็น 'หนึ่งใน' ไม่ใช่เป็นอันเดียว เนื่องจากโดยปรกติเราจะทดสอบอย่างน้อยกับ 3 ชุดข้อมูลเป็นประจำเช่น CIFAR10, CIFAR100, PascalVOC, ImageNet 1K, COCO)
#
# สิ่งที่เราสนใจในตอนแรกนี้ก็คือการทำความรู้จักกับฐานข้อมูล CIFAR10 ตามประเด็นข้างล่างนี้
# 1. ใช้โค้ดไพธอนดาวน์โหลดเซ็ตข้อมูลผ่าน Keras
# 2. สำรวจชุดข้อมูลแบบง่าย ๆ
#   * ตรวจสอบจำนวนภาพและลาเบลของภาพในเซ็ตข้อมูล
#   * แสดงภาพอันแรกในชุดข้อมูลฝึกออกมา ด้วย matplotlib
#   * ปรับขนาดภาพให้เหมาะสม
#   * ดู label ของภาพอันแรก (ลาเบลก็คือชื่อคลาสที่เราใช้เป็นเฉลยในการฝึกตัวแบบ)
# 3. แสดงข้อมูลภาพให้ดีขึ้น
#   * แสดงภาพแบบเป็นชุดด้วย subplot
#   * ตัดการวาดแกนออกไป
#   * แสดงภาพพร้อมหมายเลขลาเบล
#   * กำหนดตัวเลขในลาเบลให้เป็นชื่อที่เราเข้าใจง่ายขึ้น
#   * แสดงภาพพร้อมลาเบลแบบเป็นชื่อ

# %% [markdown]
# ## งานที่ 0: อิมพอร์ตโมดูลที่ต้องการใช้
# เราจะเริ่มจากการอิมพอร์ตโมดูลที่เราจะใช้ในแบบฝึกหัดนี้ ซึ่งประกอบไปด้วย
# 1. tensorflow
# 2. keras ที่เป็นแบบ built-in (โมดูลย่อย) ใน tensorflow (นั่นคือ tensorflow.keras ซึ่งในการอิมพอร์ตโมดูลย่อย เรานิยมทำด้วยการเขียนว่า from ... import ...)
# 3. matplotlib.pyplot
#
# <font color='red'>งานของคุณคือ</font>
# 1. จงเติมโค้ดลงในทางด้านล่างนี้เพื่ออิมพอร์ตโมดูลทั้งสี่ ซึ่งการอิมพอร์ตนี้ คุณสามารถเลือกการใช้ import as ได้ตามที่ชอบ แต่จะต้องให้สัมพันธ์กับการใช้งานทั้งหมดในแบบฝึกหัดนี้
# 2. พิมพ์หมายเลขเวอร์ชันของ tensorflow ออกมา
# 3. ทำการเรียกดูและพิมพ์ CPU หรือ GPU ที่ใช้งานได้

# %%
# [Your Work] Import modules here
# Work0
import tensorflow as tf
import tensorflow.keras as keras

import numpy as np
import matplotlib.pyplot as plt

print(tf.__version__)
gpus = tf.config.experimental.list_physical_devices('GPU')
tf.config.experimental.set_virtual_device_configuration(gpus[0],
  [tf.config.experimental.VirtualDeviceConfiguration(memory_limit=3096)])
# Out:
# 2.17.0
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-2-ed3f417f011c> in <cell line: 11>()
#       9 print(tf.__version__)
#      10 gpus = tf.config.experimental.list_physical_devices('GPU')
# ---> 11 tf.config.experimental.set_virtual_device_configuration(gpus[0],
#      12   [tf.config.experimental.VirtualDeviceConfiguration(memory_limit=3096)])
#      13
#
# IndexError: list index out of range

# %% [markdown]
# ## งานที่ 1: ดาวน์โหลดฐานข้อมูล
# การดาวน์โหลดฐานข้อมูล CIFAR10 นั้นทำได้หลายแบบ ในอดีตเราจะดาวน์โหลดมาเป็นภาพแล้วนำมาแปลงเป็นฟีทเจอร์ที่เข้ากันได้กับเฟรมเวิร์คที่เราเลือกใช้งาน แต่เนื่องจากฐานข้อมูลนี้มีขนาดไม่ใหญ่และเป็นที่นิยมอันดับต้น ๆ ในวงการ ทาง Keras (รวมถึงอีกหลาย ๆ เฟรมเวิร์ค) จึงได้เตรียมชุดข้อมูลที่จัดฟีทเจอร์ให้เหมาะกับการใช้งานไว้ให้ดาวน์โหลดผ่านส่วนต่อประสานโปรแกรม (API)

# %% [markdown]
# ### <font color='red'>งานที่ 1.1</font>: ตัวตนที่แท้จริงของชุดข้อมูลมาตรฐานใน Keras
# เราอาจจะคิดว่าชุดข้อมูลใน Keras เป็นเพียงข้อมูล แต่ตัวจริงของมันถูกจัดอยู่ในรูปของ API และเราจะมองเห็นมันเป็นชุดคำสั่งแทนที่จะเป็นข้อมูลโดยตรง ทั้งนี้ก็เพราะว่า Keras จะไม่มีข้อมูลติดมาตั้งแต่แรก เนื่องจากเราอาจจะไม่ได้ใช้
#
# ลองนึกดูว่า ถ้าเราทำวิจัยด้านภาพ เราอาจจะไม่สนใจใช้ข้อมูลเสียงหรือคลังคำศัพท์ ในขณะที่คนที่วิจัยด้านภาษาธรรมชาติจะไม่ต้องการใช้ข้อมูลภาพ เพื่อไม่ให้คนใช้งาน Keras ต้องเสียเวลาไปกับข้อมูลที่ตัวเองอาจจะไม่ได้ใช้ Keras จึงเตรียมชุดข้อมูลในรูปแบบ API และจะดาวน์โหลดมาให้เมื่อเราอยากจะใช้ ที่เด็ดสุดคือถ้าเราดาวน์โหลดมาแล้ว มันจะไม่โหลดซ้ำทำให้เราไม่เสียเวลาดาวน์โหลดซ้ำซาก
#
# เอาล่ะ พอจะจำได้ใช่ไหมว่าตอนที่เราใช้ฐานข้อมูล Fashion MNIST เราเขียนโค้ดเพื่อสร้างตัวแปรที่เชื่อมไปกับ API ฐานข้อมูลของ Fashion MNIST ตอนนี้หน้าที่ของคุณคือกลับไปดูโค้ดใน Fashion MNIST แล้วปรับให้เป็นฐานข้อมูล CIFAR10 แทน ทั้งนี้ให้เปลี่ยนชื่อตัวแปรให้เหมะสมด้วย
#
# **คำแนะนำ 1** ถ้าอยากรู้ว่าฐานข้อมูล CIFAR10 ใน Keras ต้องเรียกผ่านฟังก์ชันหรือวัตถุชื่ออะไร ให้ลองค้นด้วยคำว่า keras builtin datasets <br/>
# **คำแนะนำ 2** โดยปรกติโค้ดที่เราเห็นในเอกสารของ Keras จะเป็น Keras แบบแยกออกมานอก TensorFlow แต่ตอนนี้ เราใช้ Keras แบบที่เป็นโมดูลย่อยใน TensorFlow ดังนั้นเราอาจจะต้องปรับโค้ดให้สอดคล้องกับรูปแบบการใช้งานของเราด้วย

# %%
# [Your Work] Create a variable liking to the CIFAR10 dataset
# Work1.1
cifar10 = keras.datasets.cifar10

# %% [markdown]
# ### <font color='red'>Quick Quiz 1.1 </font>
# จากการค้นหาด้วยคำสำคัญว่า keras builtin datasets  จงระบุรายการเซ็ตข้อมูล (Datasets) แบบ builtin ของ Keras มาอย่างน้อย 7 รายการ โดยให้เขียนลงในเซลล์โน้ตบุ๊คข้างล่างนี้ตรง ??? ให้ครบถ้วน ซึ่งทำได้หากคุณดับเบิลคลิกหรือดับเบิลแท็บในเซลล์ด้านล่างนี้

# %% [markdown]
#  <font color='blue'>(พื้นที่สำหรับเติมคำตอบ) </font><br/>
# **Keras กับเซ็ตข้อมูลทั้ง 7**
# 1. CIFAR10 small image classification
# 2. CIFAR100
# 3. California housing
# 4. Fashion MNIST
# 5. IMDB
# 6. MNIST
# 7. Boston housing price regression dataset

# %% [markdown]
# ### <font color='red'>งานที่ 1.2</font>: (ดาวน์)โหลดข้อมูล CIFAR10
# เมื่อเราได้ตัวแปรสำหรับเชื่อมต่อเซ็ตข้อมูลแล้ว เราจะเรียกข้อมูลใน CIFAR10 ออกมาเก็บไว้ในลักษณะเดียวกันกับ Fashion MNIST คือมีข้อมูลชุดฝึกและทดสอบแยกกันในคนละทูเปิล (tuple) และแต่ละทูเปิลจะมีข้อมูลภาพและลาเบล (ผลเฉลย) ของแต่ะลภาพประกบกันไป
#
# **หมายเหตุ** หากเราเรียกใช้เซ็ตข้อมูลนี้เป็นครั้งแรก เครื่องจะต้องทำการดาวน์โหลดข้อมูลจากอินเตอร์เน็ต ซึ่งมีขนาดประมาณ 170 MB อาจจะต้องใช้เวลาสักหน่อยหากความเร็วอินเตอร์เน็ตของเราค่อนข้างน้อย แต่หากเรามีเซ็ตข้อมูลนี้ในเครื่องแล้ว เครื่องจะไม่ดาวน์โหลดซ้ำและจะเรียกใช้ข้อมูลที่มีอยู่แล้ว ทำให้ประหยัดเวลาได้มาก

# %%
# [Your Work] Load data from CIFAR10 and store them separately as training and testing sets.
# Work1.2
(train_images, train_labels), (test_images, test_labels) = cifar10.load_data()
train_images = train_images.astype(np.float32) / 255
test_images = test_images.astype(np.float32) / 255
# Out:
# ...
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 8s 0us/step

# %% [markdown]
# ## งานที่ 2: สำรวจชุดข้อมูลแบบง่าย ๆ
# ในงานนี้นี้เราจะตรวจสอบจำนวนภาพและลาเบลในเซ็ตข้อมูลพร้อมทั้งนำภาพมาแสดงเพื่อทวนสอบว่าเราเข้าใจรูปแบบข้อมูลและสามารถนำมาใช้ได้ตามวัตถุประสงค์
#
# ### <font color='red'>งานที่ 2.1</font>: ตรวจดูจำนวนข้อมูล
# จงเติมโค้ดข้างล่างนี้ให้สมบูรณ์ โดยจุดประสงค์ของโค้ดทางด้านล่างนี้มีสองอย่างคือ
# 1. ตรวจดูจำนวนของข้อมูลในชุดฝึกและชุดทดสอบ
# 2. ตรวจดูว่าจำนวนข้อมูลภาพกับจำนวนลาเบลเท่ากันหรือไม่
#
# **เริ่มกันที่เป้าหมายแรก ตรวจดูจำนวนภาพในเซ็ตข้อมูล**

# %%
# [Your Work] Part 1: Check the numbers of training and testing images
num_train_images = len(train_labels)
num_test_images = len(test_images)
print(num_train_images)
print(num_test_images)
# Out:
# 50000
# 10000

# %% [markdown]
# **ต่อกันที่เป้าหมายสอง ตรวจดูว่าจำนวนลาเบลในเซ็ตข้อมูลเท่ากันหรือไม่** ทั้งนี้คำว่าเท่ากันหมายความว่า จำนวนภาพในชุดฝึกต้องเท่ากับจำนวนลาเบลในชุดฝึก และจำนวนภาพในชุดทดสอบต้องเท่ากับจำนวนลาเบลในชุดทดสอบ
#
# ซึ่งเราทดสอบได้ด้วยการใช้คำสั่ง if ในโครงสร้างโค้ดด้านใต้นี้ หากจำนวนไม่เท่ากัน โปรแกรมจะสร้าง (raise) เหตุการณ์ผิดปรกติ (Exception) ขึ้นมา หน้าที่ของคุณจะต้องเขียน if ให้ถูก ส่วนที่เป็นเหตุการณ์ผิดปรกตินั้นมีเตรียมไว้ให้แล้ว หากครั้งต่อไปคุณจำเป็นต้องทำอะไรคล้าย ๆ นี้ ก็สามารถยืมโครงสร้างนี้ไปใช้ได้ เราจะได้มั่นใจในความถูกต้องของข้อมูลที่จะใช้ฝึก
#
# **หมายเหตุ** แบบฝึกหัดให้ความสำคัญกับการสำรวจข้อมูล (data exploration) ค่อนข้างมาก เนื่องจากการการฝึกตัวแบบในการเรียนรู้เชิงลึก (deep learning) มักจะใช้เวลานาน  หากเราไม่ระวัง เรามักจะพบว่าเราเสียเวลาไปหลายวันหรือหลายสัปดาห์เพียงเพื่อที่จะรู้ว่าเราทำผิด การสำรวจข้อมูลให้แน่ใจก่อน จึงเป็นแนวปฏิบัติที่เราควรทำให้เป็นนิสัย
#
# **คำแนะนำ** เหตุการณ์ผิดปรกตินี้คือ ValueError ซึ่งจะเกิดขึ้นถ้าค่าสองค่าไม่เท่ากัน ดังนั้นใน if ทางด้านใต้ เราควรจะใช้เครื่องหมาย != เพื่อดูว่าค่าสองค่าที่ควรจะเท่ากันกลับไม่เท่ากันหรือไม่ ซึ่งถ้ามันไม่เท่ากัน <font color='blue'>ซึ่งใน if แรกค่าสองค่านี้ก็คือ 'จำนวนภาพในชุดฝึก' และ 'จำนวนลาเบลในชุดฝึก' ดังนั้นคุณจะต้องเขียนคำสั่งเปรียบเทียบให้ถูกต้องตามแนวคิดว่า 'ถ้าไม่เท่ากัน แสดงว่ามีเรื่องผิดปรกติ'</font>

# %%
# [Your Work] Part 2: Check equality of the numbers of images and labels
if num_train_images == train_labels.shape:
    raise ValueError("The numbers of training images and labels do not match!")

if num_test_images == test_labels.shape:
    raise ValueError("The numbers of testing images and labels do not match!")

print("The numbers of images and labels match for both training and testing sets")
train_labels.shape
# Out:
# The numbers of images and labels match for both training and testing sets
# (50000, 1)

# %% [markdown]
# ### <font color='red'>Quick Quiz 2.1</font>: มีภาพกี่ภาพในเซ็ตข้อมูล CIFAR10 นี้
# ถ้ารันโปรแกรมมาถึงจุดนี้ได้ เราก็น่าจะตอบคำถามนี้ได้โดยอัตโนมัติ ถ้าพร้อมแล้วก็เติมคำตอบลงในไปแทน ??? ในเซลล์ข้างล่างนี้เลย มีทั้งหมด 5 ตำแหน่ง ให้ตอบให้ครบทั้ง 5 ตำแหน่ง คำถามนี้มีไว้เพื่อเช็คว่าคุณเข้าใจความหมายของสิ่งต่าง ๆ ที่ทำมาถูกต้องดีหรือไม่
#
# เช่นเดิม ให้ดับเบิลคลิกหรือดับเบิลแท็บเซลล์ข้างล่างนี้เพื่อเติมคำตอบให้สมบูรณ์

# %% [markdown]
#  <font color='blue'>(พื้นที่สำหรับเติมคำตอบ) </font><br/>
# **สรุปเกี่ยวกับจำนวนภาพและลาเบลใน CIFAR 10**
#
# ในชุดข้อมูล CIFAR10 มีภาพทั้งหมด 60000 ภาพ แบ่งเป็นภาพชุดฝึก 50000 ภาพ และเป็นภาพในชุดทุดสอบ 10000 ภาพ ซึ่งจำนวนลาเบลของชุดฝึกนั้นมี 5000 ลาเบล ส่วนลาเบลในชุดทดสอบมี 10000 ลาเบล

# %% [markdown]
# ### <font color='red'>งานที่ 2.2</font>: แสดงภาพอันแรกในชุดข้อมูลฝึก
# หากเราอยากจะแสดงข้อมูลภาพออกมาในโน้ตบุ๊ค เราสามารถใช้คำสั่ง figure เพื่อเตรียมวัตถุภาพ และใช้คำสั่ง imshow เพื่อแสดงภาพในวัตถุภาพที่สร้างขึ้นมาได้ แต่ก่อนจะแสดงภาพเรามาทำความรู้จักขนาดของภาพในเซ็ตข้อมูลกันก่อนดีกว่า
#
# **จงเรียกใช้คุณลักษณะ (attribute) shape กับชุดภาพในชุดข้อมูลฝึกเพื่อดูขนาดภาพในเซลล์ด้านใต้นี้** ทั้งนี้เราจะได้ทั้งจำนวนและขนาดภาพพ่วงออกมาด้วยกัน
#
# **คำแนะนำ** คุณลักษณะ (attribute) ก็เปรียบเหมือนกับตัวแปรตัวหนึ่งในคลาส เราจึงเรียกดูคุณลักษณะนี้ได้ผ่านการใช้ ???.shape ซึ่ง ??? ก็คือชื่อตัวแปรชุดข้อมูลภาพฝึกของเรานั่นเอง

# %%
# [Your Work] Use .shape on the set of training images to see its basic info
print(train_images.shape)
# Out:
# (50000, 32, 32, 3)

# %% [markdown]
# ###  <font color='red'>Quick Quiz 2.2a</font>: ภาพแต่ละภาพมีขนาดกี่พิกเซล
# จาก shape และความรู้เกี่ยวกับจำนวนภาพที่เรามีมาก่อนหน้า รวมถึงเราทราบว่าภาพเราเป็นภาพสี 3 แชนเนล (แชนเนลสีแดง แชนเนลสีเขียว และ แชนเนลสีน้ำเงิน) ดังนั้นภาพของเรามีขนาดเท่าใด จงตอบในพื้นที่เซลล์ด้านใต้
#
# **หมายเหตุ** ตอนนี้เราอาจจะยังไม่รู้ว่าเลขใดคือจำนวนแถวและเลขใดคือจำนวนคอลัมน์ เราจะเก็บประเด็นนี้ไว้ก่อนแล้วค่อยมาตอบคำถามนี้ในภายหลัง

# %% [markdown]
#  <font color='blue'>(พื้นที่สำหรับเติมคำตอบ) </font><br/>
# **ภาพแต่ละภาพมีขนาด** 32 x 32 พิกเซล

# %% [markdown]
# การจะแสดงภาพอันแรกออกมานั้น เราต้องดึงข้อมูลภาพอันแรกออกมาให้ได้ก่อน ซึ่งหากตัวแปรชุดภาพฝึกของเราชื่อ train_images เราจะเขียนโค้ดว่า train_images[0] เพื่อดึงข้อมูลภาพอันแรกออกมา เรื่องน่าคิดมีอยู่ว่า ก่อนหน้านี้อยู่ดี ๆ เราก็ใช้คำสั่ง shape และเมื่อกี้เราก็ใช้ [0] ซึ่งมันแสดงว่าเรารู้ก่อนหน้าว่ามันเป็น numpy array คำถามจึงมีอยู่ว่า "แล้วเรารู้ได้อย่างไรว่าข้อมูลที่ได้มาเป็นอาเรย์"
#
# ซึ่งเหตุที่เรารู้เรื่องนี้ก็เป็นไปได้สองทาง ทางแรกคืออ่านจากเอกสารของ Keras โดยตรงที่ https://keras.io/datasets/  ส่วนทางที่สองก็คือใช้ฟังก์ชัน type(...) กับข้อมูลที่เราต้องการทราบชนิด ซึ่งในที่นี้ก็คือตัวแปรชุดข้อมูลฝึกของเรานั่นเอง
#
# **จะใช้ฟังก์ชัน type กับชุดข้อมูลภาพของเราเพื่อดูชนิดของชุดข้อมูลภาพ**

# %%
# [Your Work] Check type of your training-image set
# If your code correctly works, you should get numpy.ndarray as an output.
type(train_images)
# Out:
# numpy.ndarray

# %% [markdown]
# ###  <font color='red'>Quick Quiz 2.2b</font>: เอกสารอ้างอิงเกี่ยวกับอาเรย์
# ตอนนี้เรารู้แล้วว่าชนิดข้อมูลของชุดภาพฝึกคือ numpy.ndarray และนี่เป็นเหตุผลที่เรารู้ว่าเราใช้คุณลักษณะ .shape ได้ แต่แน่นอนว่า ndarray ไม่ได้มีแค่คุณลักษณะเดียว เพื่อทดสอบว่าคุณจะค้นหาข้อมูลเกี่ยวกับ ndarray เพิ่มเติมได้เอง ขอให้คุณลองค้นหาคำว่า numpy ndarray แล้วตอบคำถามต่อไปนี้

# %% [markdown]
#  <font color='blue'>(พื้นที่สำหรับเติมคำตอบ) </font><br/>
# **จงระบุ URL ของเอกสารการเขียนโปรแกรมของคลาส ndarray** ทั้งนี้คำตอบที่เป็นไปได้มีหลากหลาย เพราะแต่ละคนอาจจะได้เวอร์ชันของไลบรารี numpy ที่แตกต่างกันมา ซึ่งในที่นี้ถือว่าถูกต้องทั้งหมด<br/>
# URL นั้นคือ: https://numpy.org/doc/stable/reference/generated/numpy.ndarray.html
#
# **จงหาว่าตามเอกสารที่คุณค้นได้ มันมีข้อมูลว่า attribute ใดที่เอาไว้ใช้ระบุจำนวน dimension ของตัวแปร ndarray** คำแนะนำ: ตามเอกสาร ข้อมูลอยู่ใกล้ ๆ กับ shape ดูขึ้นไปข้างบนของ shape แล้วลองอ่านศึกษาดูสักครู่ <br/>
# attribute ที่บอกจำนวน dimension คือ: .ndim

# %% [markdown]
# ### รู้จักกับคำว่า dimension และจำนวน dimension
# คำว่า dimension เป็นศัพท์เทคนิคที่สำคัญมากสำหรับการใช้งาน ndarray ให้ได้คล่องแคล่วและถูกต้อง ซึ่งหากเราเปิดพจนานุกรมดู เราจะพบว่า dimension แปลว่า 'มิติ' เหมือนกับคำว่า 3D ที่ที่เราแปลว่า 3 มิติ ตัว D ในที่นี้ก็คือคำว่า Dimension
#
# ส่วนคำว่า dimension ของอาเรย์และงานออกแบบสถาปัตยกรม คำว่ามิตินี้แปลว่าขนาด ซึ่งถ้าหากเราเห็นตัวเลขจาก shape ว่าเป็น (50000, 32, 32, 3) ตัวเลขในทูเปิลนี้ก็คือขนาดของอาเรย์นั่นเอง โดยมิติที่ 1 มีขนาดเป็น 50,000 และมิติ 2, 3, และ 4 มีขนาดเป็น 32, 32 และ 3 ตามลำดับ
#
# ส่วนคำว่าจำนวน dimension ก็คือจำนวนเลขระบุขนาดหรือจำนวนมิติของอาเรย์ ซึ่งตามตัวอย่างข้างบนก็คือ 4 มิติ และเราจะเรียกอาเรย์นั้นว่าอาเรย์ 4 มิติ
#
# เรื่องน่าสนใจก็คือว่า ndarray นั้นจะเป็นอาเรย์กี่มิติก็ได้ และตัว n ใน ndarray นี้ก็คือคำย่อของ n dimensional array ซึ่งแปลว่า 'อาเรย์ n มิติ' นั่นเอง

# %% [markdown]
# ###  <font color='red'>Quick Quiz 2.2c</font>: ชุดข้อมูลภาพฝึกของเรามีกี่มิติ
# จากข้อมูลทางด้านบนและคำตอบของเราใน Quiz 2.2b ให้เราเรียกใช้คุณลักษณะดังกล่าวกับตัวแปรชุดข้อมูลภาพฝึกเพื่อตรวจดูว่าชุดข้อมูลภาพฝึกเรา ในฐานะ ndarray ถือว่ามีกี่มิติ ซึ่งข้อให้เข้าใจด้วยว่า หากเราดูจากผลที่ได้จาก shape เราก็จะตอบได้เช่นกัน แต่หากเราต้องการส่งข้อมูลให้โปรแกรมอื่นทราบ เราต้องใช้ค่าจากคุณลักษณะที่เราตอบไว้ใน Quiz 2.2b เพื่อให้ได้ค่าออกมาจากโปรแกรมโดยที่เราไม่ต้องมาคอยดูค่าจาก shape แล้วป้อนข้อมูลเพิ่ม
#
# **จงใช้คุณลักษณะที่เราตอบไว้ใน Quiz 2.2b เพื่อเรียกดูจำนวนมิติของชุดภาพฝึก**

# %%
# [Your Work] Use a proper attribute to read the number of dimensions from the training-image set
# If your code correctly works, you should see 4 in the output.
print(train_images.ndim)
# Out:
# 4

# %% [markdown]
# ###  <font color='red'>งานที่ 2.2.1</font>: ดึงข้อมูลภาพอันแรกออกมาเก็บไว้ในตัวแปร
# สิ่งที่คนที่มือใหม่หัดใช้ ndarray จะไม่คุ้นก็คือว่า เราสามารถสร้างตัวแปรที่เป็นเหมือนการตัดชิ้นส่วนจากอาเรย์ใหญ่ออกมาได้ ซึ่งในที่นี้ จากภาพหลายหมื่นภาพ เราจะตัดเอามาเฉพาะภาพแรกแล้วเก็บไว้ในตัวแปรชื่อ img
#
# สมมติว่าชุดภาพฝึกของเรามีขนาดเป็น (50000, 32, 32, 3) ซึ่งมิติแรกคือจำนวนภาพ เราจะได้ว่า (32, 32, 3) ก็คือข้อมูลภาพอันหนึ่ง และหากเราต้องการภาพแรก เราก็จะตัดมันออกมาด้วยมิติแรก เพื่อให้ได้ข้อมูลมิติอื่น ๆ ที่เหลือ (งงใช่ไหม)
#
# คือชุดภาพฝึกของเราเปรียบเหมือนอาเรย์แบบนี้ [50000][32][32][3] ถ้าเราเขียนว่า train_images[0] มันจะหมายถึง train_images[0][ข้อมูลของ 0 ทั้งหมด] ทำให้เราตัดข้อมูลภาพแรกออกมาได้นั่นเอง
#
# เอาล่ะ มาลองกันดูเลยดีกว่า **จงเติมโค้ดในเซลล์ด้านล่างนี้ ดึงข้อมูลภาพอันแรกออกมาเก็บไว้ในตัวแปร img**

# %%
# [Your Work] Fill the code below. Please note that you have to put a proper variable name here for your training-image set.
img = train_images[0]

# %% [markdown]
# #### นี่คือภาพอันหนึ่งจริงหรือไม่
# ถ้าใช่ เราก็น่าจะได้อาเรย์ขนาด (32, 32, 3) ออกมา <br/>
# **จงเติมโค้ดทางด้านล่างนี้เพื่อตรวจสอบขนาดของ img**

# %%
# [Your Work] Refer to an attribute that can see the size of img
img.shape
# Out:
# (32, 32, 3)

# %% [markdown]
# #### <font color='red'>งานที่ 2.2.1</font>: ใช้ pyplot วาดภาพในตัวแปร img
# ถ้าขนาดที่ได้มาตรงตามความคาดหมาย เราก็พร้อมที่จะแสดงภาพออกมา ซึ่งในรูปแบบพื้นฐานที่สุดอันหนึ่ง เราจะทำเป็นสองจังหวะ จังหวะแรกคือใช้ฟังก์ชัน figure จาก pyplot เพื่อเตรียมสภาพแวดล้อมของการวาดภาพไว้ และจังหวะที่สองก็คือการใช้ฟังก์ชัน imshow เพื่อวาด img ออกมาบนโน้ตบุ๊ค
#
# **จงเรียกใช้ฟังก์ชัน figure และ imshow ใน pyplot เพื่อวาดภาพที่เก็บไว้ใน img** หมายเหตุ เราอาจจะไม่ได้เรียกชื่อ pyplot โดยตรงเพราะเราอิมพอร์ตมันเข้ามาเป็นชื่ออื่นผ่านคำสำคัญ as

# %%
# [Your Work] Use Functions figure and imshow to draw img
plt.figure()
plt.imshow(img)

# %% [markdown]
# ### นี่มันภาพอะไรกัน ดูไม่ออก
# มันคือภาพกบครับ แต่เนื่องจากเรามีข้อมูลเพียง 32 x 32 พิกเซล พอขยายออกมาจะดูไม่ออกหนักกว่าเดิม ถ้าย่อแล้วจะดูง่ายขึ้น ดังนั้นเราจะมาปรับขนาดภาพกัน ส่วนภาพข้างบนนั้นเอาเป็นว่าถ้ารูปมันขึ้นออกมาเป็นสีโทนน้ำตาลและมีอะไรเขียว ๆ เล็ก ๆ อยู่ทางขวาล่างก็แสดงว่าคุณทำถูกแล้ว
#
# ## <font color='red'>งานที่ 2.3</font>: ปรับขนาดภาพให้เหมาะสม
# จากภาพทางด้านบนนั้น ถ้าบอกว่ามันคือกบก็คงยากที่จะเชื่อ ดังนั้นเราจะลองปรับให้มีขนาดเล็กลงเพื่อลดปัญหาพิกเซลถูกขยายจนกลายเป็นสี่เหลี่ยมที่ดูเข้าใจยาก (ปัญหานี้ทางคอมพิวเตอร์กราฟฟิกเรียกว่า alias) ซึ่งเราทำได้หากตอนเราเรียกใช้ figure เราระบุขนาดลงไปด้วย ซึ่งหน่วยในการระบุขนาดในที่นี้คือนิ้ว และทำได้ผ่านพารามิเตอร์ชื่อ figsize
#
# **จงส่งพารามิเตอร์ระบุขนาด  <font color='blue'>figsize</font> โดยระบุขนาดผ่านทูเปิลให้ได้ภาพขนาด 1 นิ้ว x 1 นิ้ว** แนะนำว่าเปิดโค้ดเก่า ๆ จากโน้ตบุ๊ค Image Display ดูเป็นตัวอย่าง เมื่อทำได้แล้ว คุณอาจจะอยากลองระบุขนาดแบบเลขทศนิยมเช่น 0.5 x 0.5 เป็นต้น

# %%
# [Your Work] Use figsize in figure, then use imshow to check the output.
plt.figure(figsize=(1, 1))

# %% [markdown]
# ### <font color='red'>งานที่ 2.4</font>: แสดงลาเบลของภาพอันแรก
# ลาเบลในชุดข้อมูลโดยปรกติจะเป็นตัวเลข เช่น 0, 1, 2, .. ไม่ใช่ชื่อที่เป็นข้อความ ทั้งนี้เพื่อให้เครื่องตีความหมายได้อย่างรวดเร็ว การทำเป็นชื่อที่มนุษย์เข้าใจง่ายจะทำให้เครื่องทำงานช้าเนื่องจากข้อมูลตัวเลขจำนวนเต็มนั้นง่ายต่อการเปรียบเทียบในหน่วยประมวลผลและใช้พื้นที่หน่วยความจำน้อย
#
# ก่อนหน้านี้ เราดึงภาพอันแรกออกมาด้วย train_images[0] ซึ่งเราก็ทำได้กับลาเบลเช่นกัน แต่ในที่นี้จะง่ายกว่ามากเนื่องจากลาเบลแต่ละอันเป็นเลขค่าเดียวไม่ใช่ภาพ แต่เพื่อความแน่ใจ เราจะลองตรวจสอบจากขนาดของชุดลาเบลฝึกกันก่อน
#
# **จงเรียกใช้คุณลักษณะ shape กับชุดลาเบลฝึก**

# %%
# [Your Work] Check the size of trainining-label set
train_labels.shape
# Out:
# (50000, 1)

# %% [markdown]
# #### <font color='red'>งานที่ 2.4.1</font>: เข้าใจชนิดข้อมูลของลาเบล
# จากขนาดทางด้านบนที่เราได้มา เราจะพบว่ามันเป็นอาเรย์ 2 มิติทั้งที่เราคิดว่ามันน่าจะเป็นอาเรย์ 1 มิติ ทั้งนี้เพราะรูปแบบที่ Keras อยากได้เป็นเช่นนี้ เพื่อที่ทำความเข้าใจชนิดข้อมูลของลาเบลให้ดีขึ้น เราจะลองเรียกใช้ [0] กับชุดข้อมูลลาเบลฝึกในเซลล์ข้างล่างนี้
#
# **จงเรียกดูข้อมูลช่องหมายเลข 0 ของชุดลาเบลฝึก** (ถ้าตัวแปรชุดลาเบลฝึกของคุณชื่อ train_labels ให้เขียนว่า train_labels[0])

# %%
# [Your Work] Just see what is inside the first array element
# If your code is correct, you should see array([6], dtype=uint8) in the output.
train_labels[0]
# Out:
# array([6], dtype=uint8)

# %% [markdown]
# **ทำความเข้าใจกับผลลัพธ์ทางด้านบน** <br/>
# ผลลัพธ์ทางด้านบนที่ได้คือ array([6], dtype=uint8) ซึ่งมันต้องการบอกเราว่า มันเป็นอาเรย์ 1 มิติ ซึ่งข้อมูลข้างในคือเลข 6 และข้อมูลมีชนิดเป็น uint8 ซึ่งก็คือ unsigned integer ขนาด 8 บิต
#
# โดย [6] นี้ก็มีความหมายว่า 'ข้อมูลคืออาเรย์ ข้างในมีเลข 6 อยู่ตัวเดียว' ซึ่งพอดีว่ามันมีข้อมูลอยู่ตัวเดียวเห็นแล้วจะฉงนกว่าเดิม ถ้าหากมันมีเลขอื่น ๆ อยู่ด้วย เช่น 3 5 7 เราจะได้ผลลัพธ์ทางด้านบนเป็น [6, 3, 5, 7]
#
# สรุปก็คือ ผลลัพธ์ที่ได้จาก train_labels[0] เป็นอาเรย์ ไม่ใช่ตัวเลข ดังนั้นถ้าจะเอาเลขลาเบลออกมา (ซึ่งในที่นี้คือเลข 6) เราจะต้องอ้างถึงช่องข้อมูลในมิติที่สองด้วย ซึ่งสอดคล้องกับความเป็นอาเรย์ 2 มิติของชุดลาเบลฝึกที่เราทราบมาก่อนหน้า

# %% [markdown]
# #### <font color='red'>งานที่ 2.4.2</font>: เอาเลขลาเบลออกมา
# เนื่องจากมิติที่สองของอาเรย์ลาเบลฝึกมีช่องข้อมูลเดียว มันจึงเป็นไปได้เพียงทางเดียวว่าเราต้องอ้างถึงช่องหมายเลข 0 ที่มิติที่สองเพื่อดึงเอาเลขที่อยู่ข้างในออกมา
#
# **จงดึงเลขลาเบลของภาพแรกออกมาด้วยการอ้างถึงข้อมูลในอาเรย์ลาเบลฝึกผ่านการใช้วงเล็บเหลี่ยมสองอันติดกัน** พูดง่าย ๆ ก็คืออยากให้ใช้ [0][0] นั่นแหละ

# %% [markdown]
# #### Trivia: ตกลงขนาดภาพ (32, 32, 3) นี้เป็นแถวหรือคอลัมน์ที่มาก่อน
# เนื่องจากอาเรย์ที่ใช้นี้เป็นแบบ row-major หมายความว่าเลขแถวมาก่อน ดังนั้นขนาดที่เห็นจึงหมายความว่า 32 แถว, 32 คอลัมน์, 3 แชนเนล ถ้าขนาดเป็น (48, 64) ก็จะหมายถึง 48 แถว, 64 คอลัมน์

# %%
# [Your Work] Use suitable array subscripts to read the actual label number

train_labels[0][0]
# Out:
# 6

# %% [markdown]
# ## งานที่ 3: แสดงภาพให้ดีขึ้น
# ก่อนหน้านี้เราแสดงภาพออกมาได้แล้วภาพหนึ่ง มีการปรับขนาดภาพให้ดูง่ายขึ้นและยังมีการเรียกค่าลาเบลออกมาดูได้ แต่การดูทีละภาพมันไม่ทำให้เราเห็นภาพรวมของชุดข้อมูลได้ดีนัก ในครั้งนี้เราอยากจะปรับปรุงการแสดงภาพให้ออกมาเป็นชุดใหญ่ ๆ ด้วย subplot
#
# ### <font color='red'>งานที่ 3.1</font>: subplot เป็น 5 แถว 6 คอลัมน์
# การทำ subplot ประกอบด้วย 3 ขั้นตอนหลักคือ
# 1. เตรียมพื้นที่ภาพด้วย figure เหมือนกับจะแสดงภาพเดี่ยว ซึ่ง figsize ในที่นี้จะบอกขนาดเหมือนภาพเดี่ยวตามปรกติคือไม่ว่าต่อไปเราจะทำ subplot สักกี่รูปมันก็จะมีขอบเขตอยู่ในพื้นที่ที่ระบุไว้ในที่นี้ พูดง่าย ๆ ก็คือ figure เป็นเหมือนการระบุขนาดพื้นที่ผ้าใบที่จิตรกรจะละเลงสีลงไป จิตรกรจะวาดสักกี่ภาพซ้อนลงไปก็เป็นเรื่องของจิตรกร ไม่ใช่เรื่องที่ผ้าใบต้องไปคิด
# 2. การจองพื้นที่ภาพย่อย ซึ่งเราจะระบุด้วยฟังก์ชัน subplot ว่าเราจะแบ่งพื้นที่วาดให้มีทั้งหมดกี่แถวกี่คอลัมน์พร้อมทั้งระบุหมายเลขลำดับรูปที่เราจะวาดลงไปด้วย (ดูโน้ตบุ๊ค Image Display หรือ Data Exploration ประกอบ)
# 3. เรียกใช้ imshow ตามปรกติ
#
# ฟังก์ชัน imshow จะถือตามสภาพพื้นที่ล่าสุดที่เราเตรียมไว้ให้วาด ถ้าเราไม่มี subplot มันจะวาดลงไปเต็ม figure แต่ถ้ามี subplot มันก็จะถือตาม subplot อันล่าสุดที่เราเรียกใช้ ดังนั้นเราจึงจำเป็นต้องเรียก subplot ประกบกับ imshow ตลอด ถ้าเราจะวาดภาพย่อย 30 ครั้ง ก็ต้องเรียกทั้ง subplot และ imshow 30 รอบเป็นคู่กันไป
#
# **จงวาดภาพลงในพื้นที่รวมขนาดกว้าง 8 นิ้ว สูง 7 นิ้ว โดยแบ่งภาพย่อยเป็น 5 แถว 6 คอลัมน์เพื่อแสดงภาพ 30 ภาพแรกในชุดข้อมูลฝึกออกมา**
#
# คำแนะนำ ตอนระบุค่าใน figsize บางทีเราก็อดสงสัยไม่ได้ว่าตกลงมันเป็นค่าความสูงหรือความกว้างที่มาก่อน แนะนำให้อ่านข้อมูลจาก[ลิงค์นี้]( https://matplotlib.org/api/_as_gen/matplotlib.pyplot.figure.html) ซึ่งผมขอความกรุณาว่าแต่ละคนให้อ่านเอง อย่าไปพึ่งคนอื่น ไม่อย่างนั้นคุณจะเสียโอกาสในการเรียนรู้การอ่านและทำความเข้าใจเอกสารการเขียนโปรแกรม

# %%
# [Your Work] Draw 30 images with subplot
plt.figure(figsize=(8, 7))
for i in range(30):
    plt.subplot(5, 6, i + 1)
    plt.imshow(train_images[i])

# %% [markdown]
# ### <font color='red'>งานที่ 3.2</font>: ตัดการวาดแกนออกไป
# การพล็อตข้างบนมันมีการวาดแกนและเขียนตัวเลขติดออกมามากเกินไป ซึ่งข้อมูลบนแกนนี้ไม่จำเป็นสำหรับเรา ดังนั้นเราจะตัดมันออกไป ซึ่งทำได้โดยบอกกับ pyplot ก่อน imshow ว่าเราจะ xticks กับ yticks เป็นค่าว่าง คือส่งอาเรย์เปล่าไปให้ xticks กับ yticks
#
# เช่นเดิม ดูโน้ตบุ๊ค Data Exploration เป็นตัวอย่างแล้ว **จงทำ subplot 30 ภาพแรกแบบเดิมแต่ไม่แสดงการเขียนตำแหน่งในแกน x และ y**

# %%
# [Your Work] Draw 30 images without axis-ticks
plt.figure(figsize=(8, 7))
for i in range(30):
    plt.subplot(5, 6, i + 1)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(train_images[i])

# %% [markdown]
# ### <font color='red'>งานที่ 3.3</font>: แสดงภาพพร้อมหมายเลขลาเบล
# พวกตัวเลขที่วาดลงไปตามแกนที่บอกตำแหน่งนั้นเราเรียกว่า xticks, yticks ส่วนชื่อแกน x หรือข้อความที่จะเขียนลงใต้แกน x เราเรียกว่า xlabel ซึ่งหากเราดึงค่าลาเบลของแต่ละรูปออกมาได้ แล้วเอาไปใส่ใน xlabel มันก็จะทำให้รูปนั้น ๆ มีลาเบลของตัวเองอยู่ใต้ภาพ
#
# แน่นอนว่าเราต้องบอกลาเบลของแต่ละภาพให้สอดคล้องกัน ขึ้นตอนการระบุ xlabel จึงต้องเกิดขึ้นคู่ไปกับ imshow และต้องอยู่ในลูปไปด้วยกัน
#
# **จงแสดงภาพทั้ง 30 นั้นพร้อมกับหมายเลขลาเบลทางด้านใต้ภาพ** หมายเหตุ เลขลาเบลนี้เอาเฉพาะเลขนะ ถ้ามันออกมามีทั้ง [ ] และตัวเลข เช่น [6] แสดงว่าผิด เพราะเราต้องการแค่ 6 เท่านั้น

# %%
# [Your Work] Draw 30 images with label numbers
plt.figure(figsize=(8, 7))
for i in range(30):
    plt.subplot(5, 6, i + 1)  # สร้าง subplot
    plt.xticks([])  # ปิดการแสดงแกน x
    plt.yticks([])  # ปิดการแสดงแกน y
    plt.imshow(train_images[i])  # แสดงภาพ
    plt.xlabel(f'{train_labels[i][0]}', fontsize=10)

# %% [markdown]
# ### <font color='red'>Quick Quiz 3.3</font>: ลาเบลแต่ละอันคืออะไร
# สมมติว่าชื่อลาเบล (ชื่อคลาส) ใน CIFAR10 มีดังนี้ frog, cat, horse, dog, bird (สัตว์ปีก), airplane, deer, automobile (รถยนต์ส่วนบุคคล), truck (รถบรรทุก), และ ship จงระบุว่าหมายเลขลาเบลแต่ละอันตรงกับชื่ออะไร
#
# คำแนะนำ ถ้าไม่แน่ใจ ลองขยายขนาดพื้นที่แสดงผลตรง figsize แล้วเอาออกมาแสดงสัก 100 ภาพ

# %% [markdown]
#  <font color='blue'>(พื้นที่สำหรับเติมคำตอบ) </font><br/>
# **จงระบุชื่อลาเบลของหมายเลขทั้ง 10 นี้ให้ถูกต้อง**<br>
#
# 0. 6
# 1. 9
# 2. 9
# 3. 4
# 4. 1
# 5. 1
# 6. 2
# 7. 7
# 8. 8
# 9. 3

# %% [markdown]
# ### <font color='red'>งานที่ 3.4</font>: กำหนดตัวเลขในลาเบลให้เป็นชื่อที่เราเข้าใจง่ายขึ้น
# เราสามารถเชื่อมโยงตัวเลขลาเบลกับชื่อของมันได้ผ่านลิสต์ คือหากเรากรอกชื่อลาเบลลงไปในลิสต์ตามลำดับ 0, 1, 2, ..., 9 ชื่อแรกในลิสต์จะเชื่อมโยงกับเลข 0 ส่วนชื่อที่สองจะเชื่อมโยงกับเลข 1 และเรียงตามลำดับไปเช่นนี้  ที่เป็นอย่างนี้เพราะของในลิสต์จะถูกเรียงตามลำดับเลขพวกนี้อยู่แล้วในไพธอน
#
# **จงนำข้อมูลชื่อลาเบลไปใส่ในลิสต์ชื่อ names โดยเรียงตามลำดับ 0 ถึง 9** และเพื่อความกะทัดรัด เราจะย่อคำว่า automobile ให้เหลือเพียงคำว่า auto และ airplane เหลือสั้นว่า plane

# %%
# [Your Work] Create a list of label names
# names = []
names = [
    "airplane",
    "automobile",
    "bird",
    "cat",
    "deer",
    "dog",
    "frog",
    "horse",
    "ship",
    "truck"
]
names[1] = "auto"
names[0] = "plane"
print(names)
# Out:
# ['plane', 'auto', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %% [markdown]
# ### <font color='red'>งานที่ 3.4.1</font>: แสดงภาพพร้อมลาเบลแบบเป็นชื่อ
# จากเดิมเรากำหนดค่าของ xlabel ด้วยค่าตัวเลข แต่ในตอนนี้เราต้องการแปลงค่าตัวเลขให้กลายเป็นชื่อผ่านลิสต์ names ซึ่งเชื่อมโยงตัวเลขกับชื่อไว้โดยปริยาย เช่น ถ้าเราเขียนว่า names[0] เราจะได้ 'plane' และถ้าเขียนว่า names[6] จะได้ frog เป็นต้น
#
# **จงแสดงภาพ 30 ภาพแรก พร้อมทั้งชื่อลาเบลทางด้านใต้ภาพแต่ละอัน**

# %%
# [Your Work] Draw 30 images with proper label names
plt.figure(figsize=(8, 7))
for i in range(30):
    plt.subplot(5, 6, i + 1)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(train_images[i])
    plt.xlabel(names[train_labels[i][0]])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-aca6a04051da> in <cell line: 2>()
#       1 # [Your Work] Draw 30 images with proper label names
# ----> 2 plt.figure(figsize=(8, 7))
#       3 for i in range(30):
#       4     plt.subplot(5, 6, i + 1)
#       5     plt.xticks([])
#
# NameError: name 'plt' is not defined

# %% [markdown]
# ### <font color='red'>งานที่ 3.4.2</font>: แสดงภาพพร้อมลาเบลแบบเป็นชื่อ
# ถ้าอยากแสดงภาพตั้งแต่ index ที่ M ถึง N อยากทราบว่าจะต้องแก้ไขโค้ดของงานก่อนหน้าให้เป็นอย่างไร
#
# **จงแสดงภาพที่ M ถึง N ภาพแรก พร้อมทั้งชื่อลาเบลทางด้านใต้ภาพแต่ละอัน**

# %%
# [Your Work] Draw images from index M to N with proper label names
plt.figure(figsize=(8, 7))
for i in range(30):
    plt.subplot(5, 6, i + 1)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(train_images[i])
    plt.xlabel(names[train_labels[i][0]])

# %% [markdown]
# --เสร็จแล้ว เย้
